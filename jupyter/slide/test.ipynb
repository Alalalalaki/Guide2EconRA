# %% [markdown]
# # Test on JupyterLab Slide

# %% [markdown]
# ## Info
#
# - official document: https://jupyterlab.readthedocs.io/en/latest/user/export.html#reveal-js-slides
# - the RISE extension of jupyter notebook has yet not worked for jupyterlab, see this [issue](https://github.com/damianavila/RISE/issues/270)

# %% [markdown]
# ## It seems to be a good idea to add a line after slide titles
# ---
#
# - more clear when writing
# - more clear when showing

# %% [markdown]
# ## Test markdown effects
# ---
#
# some text ...
#
# try **mark down** see *if* it ~~works~~
#
# [a link]()

# %% [markdown]
# ## Some Code
# ---
#
# - Put text and code in the same slide by simply setting Slide Type of other chunks to `-`

# %%
df = pd.util.testing.makeDataFrame().reset_index(drop=True)
df.head()
# Out:
# /Users/alalalalaki/anaconda3/envs/py38/lib/python3.8/site-packages/pandas/util/__init__.py:12: FutureWarning: pandas.util.testing is deprecated. Use the functions in the public API at pandas.testing instead.
#   import pandas.util.testing
#       A     B     C     D
# 0 1.19  -0.43 -0.24 -2.24
# 1 1.35  0.28  -0.18 -1.34
# 2 -1.17 0.98  -0.11 -0.15
# 3 -1.45 -1.42 0.30  0.07
# 4 -0.96 -0.01 -0.55 0.40

# %% [markdown]
# add some text in bottom

# %% [markdown]
# - Alternatively you can set Slide Type to `Sub-Slide` (arrow down) if the code or the result needs more space

# %%
pd.concat([df.tail(10), df.tail(10)], axis=1)
# Out:
#        A     B     C     D     A     B     C     D
# 20 -2.26 -0.84 -1.04 -0.00 -2.26 -0.84 -1.04 -0.00
# 21 -0.53 -0.01 -1.35 -0.40 -0.53 -0.01 -1.35 -0.40
# 22 2.51  0.49  -0.33 0.22  2.51  0.49  -0.33 0.22
# 23 -1.39 -0.22 0.53  0.56  -1.39 -0.22 0.53  0.56
# 24 -0.99 0.94  0.48  0.96  -0.99 0.94  0.48  0.96
# 25 -0.32 -0.32 -1.16 -0.42 -0.32 -0.32 -1.16 -0.42
# 26 0.68  -0.32 -0.48 -1.29 0.68  -0.32 -0.48 -1.29
# 27 -0.05 0.84  -1.34 -1.93 -0.05 0.84  -1.34 -1.93
# 28 0.60  -0.09 0.93  -0.01 0.60  -0.09 0.93  -0.01
# 29 2.68  0.31  -0.24 1.35  2.68  0.31  -0.24 1.35

# %% [markdown]
# ## Some Plot
# ---
#
# - It is also cool to set Slide Type to `Fragment` (again arrow down)

# %%
df.plot();

# %% [markdown]
# - say something more

# %% [markdown]
# ## Convert Notes:
# ---
#
# - use `!jupyter nbconvert test.ipynb --to slides`
#     - this convert the file in current dir and cover the past one
# - if you want to suppres the code input, see this [issue](https://github.com/jupyterlab/jupyterlab/issues/4100)
#     - but it need use terminal to nbconvert the slides
#     - `jupyter nbconvert presentation.ipynb --config my_slide_config.py`

# %%
# run the code to convert the slide
# by setting Slide Type to "Skip"
# this would not be shown in slides

# !jupyter nbconvert test.ipynb --to slides
# Out:
# [NbConvertApp] Converting notebook test.ipynb to slides
# [NbConvertApp] Writing 408206 bytes to test.slides.html

# %% [markdown]
# ## Alternative:
# ---
#
# - You can use Rstudio and Rmarkdown to produce python slides as well, which is more flexible
